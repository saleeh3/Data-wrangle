# %% [markdown]
# ### Act report
#
# Introduction
#
# this wrangle and analyze is part of data analysis nanodegree the projcet requier to gather data from three source , assess , clean and finaly some visualization .
#
# Most dog rated
#
#
# during analysis i found rating for dog type which most dog type rated ?
# these qusetion are answered by visualiztion
#
# the most rated was golden_retiever

# %% [markdown]
# ![mostd%20rated%20dog.png](attachment:mostd%20rated%20dog.png)

# %% [markdown]
# ## relation between retweet and favorite
#
# strong relation between retweet and favorite , incrase favorite  and retweet high crroelated

# %% [markdown]
# ![retwwet%20_favorte.png](attachment:retwwet%20_favorte.png)
